# %%
# TODO: check out ways to keep things secret:
#  - https://nbdime.readthedocs.io/en/latest/config.html#configuring-ignores    
#    python module that can do a bunch of interesting stuff with notebooks 
#    [check out "Ignores"]
#    
#  - https://github.com/kynan/nbstripout
#    strips output [pre-commit?] 


import pandas as pd

filenames = [
    "ACS_MD_15_5YR_DP03",
    "ACS_MD_15_5YR_DP05",
    "cgr-definitions-table",
    "cgr-premiums-table",
    "territory-definitions-table",
]

dfs = [pd.read_csv(f"../data/private/car-insurance/{filename}.csv") for filename in filenames]

for df in dfs:
    print(df)
